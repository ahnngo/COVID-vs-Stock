# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#df = data.DataReader(['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC'],'yahoo', start, end)

# %% [markdown]
# ## Top 15 largest banks in the USA as of Sept. 30, 2021 by Federal Reserve

# %%
bank_data = pd.read_html('https://www.bankrate.com/banking/biggest-banks-in-america/')

# %%
bank_data[0].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_953b0_" ><thead>    <tr>        <th class="col_heading level0 col0" >Rank</th>        <th class="col_heading level0 col1" >Bank name</th>        <th class="col_heading level0 col2" >Total assets</th>        <th class="col_heading level0 col3" >Previous rank</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_953b0_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_953b0_row0_col1" class="data row0 col1" >JPMorgan Chase & Co.</td>
#                         <td id="T_953b0_row0_col2" class="data row0 col2" >$3.29 trillion</td>
#                         <td id="T_953b0_row0_col3" class="data row0 col3" >1.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_953b0_row1_col1" class="data row1 col1" >Bank of America Corp.</td>
#                         <td id="T_953b0_row1_col2" class="data row1 col2" >$2.4 trillion</td>
#                         <td id="T_953b0_row1_col3" class="data row1 col3" >2.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_953b0_row2_col1" class="data row2 col1" >Wells Fargo & Co.</td>
#                         <td id="T_953b0_row2_col2" class="data row2 col2" >$1.79 trillion</td>
#                         <td id="T_953b0_row2_col3" class="data row2 col3" >3.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_953b0_row3_col1" class="data row3 col1" >Citigroup Inc.</td>
#                         <td id="T_953b0_row3_col2" class="data row3 col2" >$1.70 trillion</td>
#                         <td id="T_953b0_row3_col3" class="data row3 col3" >4.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_953b0_row4_col1" class="data row4 col1" >U.S. Bancorp</td>
#                         <td id="T_953b0_row4_col2" class="data row4 col2" >$556.81 billion</td>
#                         <td id="T_953b0_row4_col3" class="data row4 col3" >5.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_953b0_row5_col1" class="data row5 col1" >Truist Bank</td>
#                         <td id="T_953b0_row5_col2" class="data row5 col2" >$516.78 billion</td>
#                         <td id="T_953b0_row5_col3" class="data row5 col3" >6.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_953b0_row6_col1" class="data row6 col1" >PNC Financial Services Group Inc.</td>
#                         <td id="T_953b0_row6_col2" class="data row6 col2" >$462.39 billion</td>
#                         <td id="T_953b0_row6_col3" class="data row6 col3" >7.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_953b0_row7_col1" class="data row7 col1" >TD Group US Holdings LLC</td>
#                         <td id="T_953b0_row7_col2" class="data row7 col2" >$413.13 billion</td>
#                         <td id="T_953b0_row7_col3" class="data row7 col3" >8.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row8_col0" class="data row8 col0" >9</td>
#                         <td id="T_953b0_row8_col1" class="data row8 col1" >Goldman Sachs Group Inc.</td>
#                         <td id="T_953b0_row8_col2" class="data row8 col2" >$387.38 billion</td>
#                         <td id="T_953b0_row8_col3" class="data row8 col3" >11.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row9_col0" class="data row9 col0" >10</td>
#                         <td id="T_953b0_row9_col1" class="data row9 col1" >Bank of New York Mellon Corp.</td>
#                         <td id="T_953b0_row9_col2" class="data row9 col2" >$385.83 billion</td>
#                         <td id="T_953b0_row9_col3" class="data row9 col3" >9.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row10_col0" class="data row10 col0" >11</td>
#                         <td id="T_953b0_row10_col1" class="data row10 col1" >Capital One Financial Corp.</td>
#                         <td id="T_953b0_row10_col2" class="data row10 col2" >$372.05 billion</td>
#                         <td id="T_953b0_row10_col3" class="data row10 col3" >10.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row11_col0" class="data row11 col0" >12</td>
#                         <td id="T_953b0_row11_col1" class="data row11 col1" >State Street Corp.</td>
#                         <td id="T_953b0_row11_col2" class="data row11 col2" >$319.44 billion</td>
#                         <td id="T_953b0_row11_col3" class="data row11 col3" >12.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row12_col0" class="data row12 col0" >13</td>
#                         <td id="T_953b0_row12_col1" class="data row12 col1" >Fifth Third Bank</td>
#                         <td id="T_953b0_row12_col2" class="data row12 col2" >$206.38 billion</td>
#                         <td id="T_953b0_row12_col3" class="data row12 col3" >13.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row13_col0" class="data row13 col0" >14</td>
#                         <td id="T_953b0_row13_col1" class="data row13 col1" >HSBC</td>
#                         <td id="T_953b0_row13_col2" class="data row13 col2" >$199.61 billion</td>
#                         <td id="T_953b0_row13_col3" class="data row13 col3" >14.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_953b0_row14_col0" class="data row14 col0" >15</td>
#                         <td id="T_953b0_row14_col1" class="data row14 col1" >Silicon Valley Bank</td>
#                         <td id="T_953b0_row14_col2" class="data row14 col2" >$188.33 billion</td>
#                         <td id="T_953b0_row14_col3" class="data row14 col3" >nan</td>
#             </tr>
#     </tbody></table>

# %%
tickers = ['JPM', 'BAC', 'WFC', 'C', 'USB', 'TFC', 'PNC', 'GLG', 'GS', 'BK', 'COF', 'STT', 'FITB', 'HSBC', 'SIVB']

# %%
bank_data[0].insert(2, 'Ticker', tickers)

# %%
bank_data[0].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_d884a_" ><thead>    <tr>        <th class="col_heading level0 col0" >Rank</th>        <th class="col_heading level0 col1" >Bank name</th>        <th class="col_heading level0 col2" >Ticker</th>        <th class="col_heading level0 col3" >Total assets</th>        <th class="col_heading level0 col4" >Previous rank</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d884a_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d884a_row0_col1" class="data row0 col1" >JPMorgan Chase & Co.</td>
#                         <td id="T_d884a_row0_col2" class="data row0 col2" >JPM</td>
#                         <td id="T_d884a_row0_col3" class="data row0 col3" >$3.29 trillion</td>
#                         <td id="T_d884a_row0_col4" class="data row0 col4" >1.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_d884a_row1_col1" class="data row1 col1" >Bank of America Corp.</td>
#                         <td id="T_d884a_row1_col2" class="data row1 col2" >BAC</td>
#                         <td id="T_d884a_row1_col3" class="data row1 col3" >$2.4 trillion</td>
#                         <td id="T_d884a_row1_col4" class="data row1 col4" >2.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_d884a_row2_col1" class="data row2 col1" >Wells Fargo & Co.</td>
#                         <td id="T_d884a_row2_col2" class="data row2 col2" >WFC</td>
#                         <td id="T_d884a_row2_col3" class="data row2 col3" >$1.79 trillion</td>
#                         <td id="T_d884a_row2_col4" class="data row2 col4" >3.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_d884a_row3_col1" class="data row3 col1" >Citigroup Inc.</td>
#                         <td id="T_d884a_row3_col2" class="data row3 col2" >C</td>
#                         <td id="T_d884a_row3_col3" class="data row3 col3" >$1.70 trillion</td>
#                         <td id="T_d884a_row3_col4" class="data row3 col4" >4.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_d884a_row4_col1" class="data row4 col1" >U.S. Bancorp</td>
#                         <td id="T_d884a_row4_col2" class="data row4 col2" >USB</td>
#                         <td id="T_d884a_row4_col3" class="data row4 col3" >$556.81 billion</td>
#                         <td id="T_d884a_row4_col4" class="data row4 col4" >5.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_d884a_row5_col1" class="data row5 col1" >Truist Bank</td>
#                         <td id="T_d884a_row5_col2" class="data row5 col2" >TFC</td>
#                         <td id="T_d884a_row5_col3" class="data row5 col3" >$516.78 billion</td>
#                         <td id="T_d884a_row5_col4" class="data row5 col4" >6.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_d884a_row6_col1" class="data row6 col1" >PNC Financial Services Group Inc.</td>
#                         <td id="T_d884a_row6_col2" class="data row6 col2" >PNC</td>
#                         <td id="T_d884a_row6_col3" class="data row6 col3" >$462.39 billion</td>
#                         <td id="T_d884a_row6_col4" class="data row6 col4" >7.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_d884a_row7_col1" class="data row7 col1" >TD Group US Holdings LLC</td>
#                         <td id="T_d884a_row7_col2" class="data row7 col2" >GLG</td>
#                         <td id="T_d884a_row7_col3" class="data row7 col3" >$413.13 billion</td>
#                         <td id="T_d884a_row7_col4" class="data row7 col4" >8.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row8_col0" class="data row8 col0" >9</td>
#                         <td id="T_d884a_row8_col1" class="data row8 col1" >Goldman Sachs Group Inc.</td>
#                         <td id="T_d884a_row8_col2" class="data row8 col2" >GS</td>
#                         <td id="T_d884a_row8_col3" class="data row8 col3" >$387.38 billion</td>
#                         <td id="T_d884a_row8_col4" class="data row8 col4" >11.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row9_col0" class="data row9 col0" >10</td>
#                         <td id="T_d884a_row9_col1" class="data row9 col1" >Bank of New York Mellon Corp.</td>
#                         <td id="T_d884a_row9_col2" class="data row9 col2" >BK</td>
#                         <td id="T_d884a_row9_col3" class="data row9 col3" >$385.83 billion</td>
#                         <td id="T_d884a_row9_col4" class="data row9 col4" >9.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row10_col0" class="data row10 col0" >11</td>
#                         <td id="T_d884a_row10_col1" class="data row10 col1" >Capital One Financial Corp.</td>
#                         <td id="T_d884a_row10_col2" class="data row10 col2" >COF</td>
#                         <td id="T_d884a_row10_col3" class="data row10 col3" >$372.05 billion</td>
#                         <td id="T_d884a_row10_col4" class="data row10 col4" >10.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row11_col0" class="data row11 col0" >12</td>
#                         <td id="T_d884a_row11_col1" class="data row11 col1" >State Street Corp.</td>
#                         <td id="T_d884a_row11_col2" class="data row11 col2" >STT</td>
#                         <td id="T_d884a_row11_col3" class="data row11 col3" >$319.44 billion</td>
#                         <td id="T_d884a_row11_col4" class="data row11 col4" >12.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row12_col0" class="data row12 col0" >13</td>
#                         <td id="T_d884a_row12_col1" class="data row12 col1" >Fifth Third Bank</td>
#                         <td id="T_d884a_row12_col2" class="data row12 col2" >FITB</td>
#                         <td id="T_d884a_row12_col3" class="data row12 col3" >$206.38 billion</td>
#                         <td id="T_d884a_row12_col4" class="data row12 col4" >13.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row13_col0" class="data row13 col0" >14</td>
#                         <td id="T_d884a_row13_col1" class="data row13 col1" >HSBC</td>
#                         <td id="T_d884a_row13_col2" class="data row13 col2" >HSBC</td>
#                         <td id="T_d884a_row13_col3" class="data row13 col3" >$199.61 billion</td>
#                         <td id="T_d884a_row13_col4" class="data row13 col4" >14.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_d884a_row14_col0" class="data row14 col0" >15</td>
#                         <td id="T_d884a_row14_col1" class="data row14 col1" >Silicon Valley Bank</td>
#                         <td id="T_d884a_row14_col2" class="data row14 col2" >SIVB</td>
#                         <td id="T_d884a_row14_col3" class="data row14 col3" >$188.33 billion</td>
#                         <td id="T_d884a_row14_col4" class="data row14 col4" >nan</td>
#             </tr>
#     </tbody></table>

# %%
start = datetime.datetime(2019, 6, 1)
end = datetime.datetime(2022, 3, 14)

# %%
df = data.DataReader(tickers,'yahoo', start, end)

# %%
JPM = data.DataReader("JPM", 'yahoo', start, end)
BAC = data.DataReader("BAC", 'yahoo', start, end)
WFC = data.DataReader("WFC", 'yahoo', start, end)
C = data.DataReader("C", 'yahoo', start, end)
USB = data.DataReader("USB", 'yahoo', start, end)
TFC = data.DataReader("TFC", 'yahoo', start, end)
PNC = data.DataReader("PNC", 'yahoo', start, end)
GLG = data.DataReader("GLG", 'yahoo', start, end)
GS = data.DataReader("GS", 'yahoo', start, end)
BK = data.DataReader("BK", 'yahoo', start, end)
COF = data.DataReader("COF", 'yahoo', start, end)
STT = data.DataReader("STT", 'yahoo', start, end)
FITB = data.DataReader("FITB", 'yahoo', start, end)
HSBC = data.DataReader("HSBC", 'yahoo', start, end)
SIVB = data.DataReader("SIVB", 'yahoo', start, end)

# %%
bank_stocks = pd.concat([JPM, BAC, WFC, C, USB, TFC, PNC, GLG, GS, BK, COF, STT, FITB, HSBC, SIVB],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#                    JPM                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2019-06-03  106.860001  105.300003  105.800003  106.459999  11680700.0
# 2019-06-04  109.900002  107.129997  107.849998  109.739998  12858600.0
# 2019-06-05  110.379997  108.639999  109.860001  110.129997   8340500.0
# 2019-06-06  110.870003  108.930000  110.150002  110.370003   8726700.0
# 2019-06-07  110.019997  108.959999  109.699997  109.160004  10618900.0
#
#                               BAC                               ...  \
#              Adj Close       High        Low   Open      Close  ...
# Date                                                            ...
# 2019-06-03   98.129333  26.990000  26.400000  26.59  26.680000  ...
# 2019-06-04  101.152672  27.950001  27.139999  27.18  27.920000  ...
# 2019-06-05  101.512161  28.010000  27.459999  27.84  27.910000  ...
# 2019-06-06  101.733383  28.040001  27.540001  27.76  27.879999  ...
# 2019-06-07  100.618073  27.790001  27.420000  27.75  27.530001  ...
#
#                  HSBC                                         SIVB  \
#                  Open      Close     Volume  Adj Close        High
# Date
# 2019-06-03  40.869999  40.840000  1837300.0  36.114449  204.679993
# 2019-06-04  41.090000  41.189999  1873200.0  36.423958  214.750000
# 2019-06-05  41.110001  41.139999  1450100.0  36.379738  216.389999
# 2019-06-06  41.029999  41.180000  1575100.0  36.415115  215.369995
# 2019-06-07  41.450001  41.459999  1411700.0  36.662712  215.149994
#
#
#                    Low        Open       Close   Volume   Adj Close
# Date
# 2019-06-03  197.339996  200.419998  202.779999  1241700  202.779999
# 2019-06-04  205.990005  206.820007  214.669998   762200  214.669998
# 2019-06-05  208.500000  214.910004  212.270004   538000  212.270004
# 2019-06-06  210.830002  211.880005  214.500000   326100  214.500000
# 2019-06-07  210.529999  213.000000  212.940002   392400  212.940002
#
# [5 rows x 90 columns]

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker         JPM                                                  \
# Stock Info         High         Low        Open       Close      Volume
# Date
# 2019-06-03   106.860001  105.300003  105.800003  106.459999  11680700.0
# 2019-06-04   109.900002  107.129997  107.849998  109.739998  12858600.0
# 2019-06-05   110.379997  108.639999  109.860001  110.129997   8340500.0
# 2019-06-06   110.870003  108.930000  110.150002  110.370003   8726700.0
# 2019-06-07   110.019997  108.959999  109.699997  109.160004  10618900.0
#
# Bank Ticker                    BAC                               ...  \
# Stock Info    Adj Close       High        Low   Open      Close  ...
# Date                                                             ...
# 2019-06-03    98.129333  26.990000  26.400000  26.59  26.680000  ...
# 2019-06-04   101.152672  27.950001  27.139999  27.18  27.920000  ...
# 2019-06-05   101.512161  28.010000  27.459999  27.84  27.910000  ...
# 2019-06-06   101.733383  28.040001  27.540001  27.76  27.879999  ...
# 2019-06-07   100.618073  27.790001  27.420000  27.75  27.530001  ...
#
# Bank Ticker       HSBC                                         SIVB  \
# Stock Info        Open      Close     Volume  Adj Close        High
# Date
# 2019-06-03   40.869999  40.840000  1837300.0  36.114449  204.679993
# 2019-06-04   41.090000  41.189999  1873200.0  36.423958  214.750000
# 2019-06-05   41.110001  41.139999  1450100.0  36.379738  216.389999
# 2019-06-06   41.029999  41.180000  1575100.0  36.415115  215.369995
# 2019-06-07   41.450001  41.459999  1411700.0  36.662712  215.149994
#
# Bank Ticker
# Stock Info          Low        Open       Close   Volume   Adj Close
# Date
# 2019-06-03   197.339996  200.419998  202.779999  1241700  202.779999
# 2019-06-04   205.990005  206.820007  214.669998   762200  214.669998
# 2019-06-05   208.500000  214.910004  212.270004   538000  212.270004
# 2019-06-06   210.830002  211.880005  214.500000   326100  214.500000
# 2019-06-07   210.529999  213.000000  212.940002   392400  212.940002
#
# [5 rows x 90 columns]

# %% [markdown]
# ## EDA

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# JPM     171.779999
# BAC      49.380001
# WFC      59.060001
# C        81.910004
# USB      63.250000
# TFC      67.410004
# PNC     226.449997
# GLG       3.980000
# GS      423.850006
# BK       63.660000
# COF     177.729996
# STT     103.769997
# FITB     50.450001
# HSBC     42.099998
# SIVB    755.030029
# dtype: float64

# %%
bank_stocks_max_min = pd.DataFrame({'Max': bank_stocks.xs(key='Close',axis=1,level='Stock Info').max(), 
                                    'Date Max': bank_stocks.xs(key='Close',axis=1,level='Stock Info').idxmax(),
                                    'Min': bank_stocks.xs(key='Close',axis=1,level='Stock Info').min(), 
                                    'Date Min': bank_stocks.xs(key='Close',axis=1,level='Stock Info').idxmin()})

# %%
bank_stocks_max_min
# Out:
#                     Max   Date Max         Min   Date Min
# Bank Ticker
# JPM          171.779999 2021-10-22   79.029999 2020-03-23
# BAC           49.380001 2022-02-08   18.080000 2020-03-23
# WFC           59.060001 2022-02-09   21.139999 2020-10-29
# C             81.910004 2020-01-14   35.389999 2020-03-23
# USB           63.250000 2022-01-14   28.930000 2020-03-23
# TFC           67.410004 2022-01-14   25.690001 2020-03-23
# PNC          226.449997 2022-01-13   80.639999 2020-03-23
# GLG            3.980000 2020-08-13    0.180000 2022-02-24
# GS           423.850006 2021-11-02  134.970001 2020-03-23
# BK            63.660000 2022-02-09   27.490000 2020-03-23
# COF          177.729996 2021-08-13   42.270000 2020-04-03
# STT          103.769997 2022-01-14   43.209999 2020-03-23
# FITB          50.450001 2022-01-14   11.670000 2020-03-18
# HSBC          42.099998 2019-07-03   18.110001 2020-09-25
# SIVB         755.030029 2021-11-03  130.979996 2020-03-16

# %%
bank_stocks_max_min['Date Max'].value_counts().head(1)
# Out:
# 2022-01-14    4
# Name: Date Max, dtype: int64

# %%
bank_stocks_max_min['Date Min'].value_counts().head(1)
# Out:
# 2020-03-23    9
# Name: Date Min, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='Date Max', y='Max', marker='v', s= 20, data=bank_stocks_max_min)
plt.scatter(x='Date Min', y='Min', s= 20, data=bank_stocks_max_min)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('Maximum and Minimum Close Price of Stocks by Time')
plt.legend()

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick +' return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             JPM return  BAC return  WFC return  C return  USB return  \
# Date
# 2019-06-03         NaN         NaN         NaN       NaN         NaN
# 2019-06-04    0.030810    0.046477    0.026056  0.052228    0.029174
# 2019-06-05    0.003554   -0.000358    0.003940 -0.001518    0.005746
# 2019-06-06    0.002179   -0.001075    0.001308  0.010490    0.004951
# 2019-06-07   -0.010963   -0.012554   -0.006315 -0.011735   -0.001895
#
#             TFC return  PNC return  GLG return  GS return  BK return  \
# Date
# 2019-06-03         NaN         NaN         NaN        NaN        NaN
# 2019-06-04    0.037391    0.034349    0.031746   0.036519   0.028804
# 2019-06-05    0.010240    0.006372   -0.061538  -0.007584  -0.015353
# 2019-06-06   -0.001622   -0.003724   -0.016393   0.007270   0.004815
# 2019-06-07   -0.008528   -0.006505   -0.100000   0.000000   0.013236
#
#             COF return  STT return  FITB return  HSBC return  SIVB return
# Date
# 2019-06-03         NaN         NaN          NaN          NaN          NaN
# 2019-06-04    0.032614    0.029107     0.028604     0.008570     0.058635
# 2019-06-05   -0.000222   -0.033837    -0.005854    -0.001214    -0.011180
# 2019-06-06    0.005117    0.009698    -0.002944     0.000972     0.010505
# 2019-06-07   -0.001107    0.007115    -0.009598     0.006799    -0.007273

# %%
returns_max_min = pd.DataFrame({'Max': returns.max(), 
                                    'Date Max': returns.idxmax(),
                                    'Min': returns.min(), 
                                    'Date Min': returns.idxmin()})

# %%
returns_max_min
# Out:
#                   Max   Date Max       Min   Date Min
# JPM return   0.180125 2020-03-13 -0.149649 2020-03-16
# BAC return   0.177962 2020-03-13 -0.153973 2020-03-16
# WFC return   0.145347 2020-03-24 -0.158676 2020-03-12
# C return     0.179843 2020-03-13 -0.192986 2020-03-16
# USB return   0.173679 2020-03-13 -0.144405 2020-03-09
# TFC return   0.172441 2020-03-24 -0.190955 2020-03-16
# PNC return   0.129434 2020-03-13 -0.159002 2020-03-16
# GLG return   0.388889 2022-02-25 -0.219298 2021-03-10
# GS return    0.175803 2020-03-13 -0.127053 2020-03-16
# BK return    0.156165 2020-03-13 -0.145034 2020-03-16
# COF return   0.187544 2020-03-24 -0.238742 2020-03-16
# STT return   0.223192 2020-03-13 -0.189263 2020-03-16
# FITB return  0.185033 2020-03-24 -0.217811 2020-03-16
# HSBC return  0.103680 2020-11-09 -0.102463 2020-04-01
# SIVB return  0.143911 2020-03-13 -0.163975 2020-03-16

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='Date Max', y='Max', marker='v', s= 20, data=returns_max_min)
plt.scatter(x='Date Min', y='Min', s= 20, data=returns_max_min)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('Maximum and Minimum Change in Close Price of Stocks by Time')
plt.legend()

# %%
returns
# Out:
#             JPM return  BAC return  WFC return  C return  USB return  \
# Date
# 2019-06-03         NaN         NaN         NaN       NaN         NaN
# 2019-06-04    0.030810    0.046477    0.026056  0.052228    0.029174
# 2019-06-05    0.003554   -0.000358    0.003940 -0.001518    0.005746
# 2019-06-06    0.002179   -0.001075    0.001308  0.010490    0.004951
# 2019-06-07   -0.010963   -0.012554   -0.006315 -0.011735   -0.001895
# ...                ...         ...         ...       ...         ...
# 2022-03-08   -0.007043    0.006521    0.014189 -0.012241    0.002825
# 2022-03-09    0.040062    0.063488    0.058115  0.019683    0.023662
# 2022-03-10   -0.011841   -0.009016   -0.003051 -0.019124   -0.027885
# 2022-03-11   -0.022524   -0.008360   -0.011018 -0.013120   -0.006416
# 2022-03-14    0.009931    0.021572    0.028678  0.001292    0.024691
#
#             TFC return  PNC return  GLG return  GS return  BK return  \
# Date
# 2019-06-03         NaN         NaN         NaN        NaN        NaN
# 2019-06-04    0.037391    0.034349    0.031746   0.036519   0.028804
# 2019-06-05    0.010240    0.006372   -0.061538  -0.007584  -0.015353
# 2019-06-06   -0.001622   -0.003724   -0.016393   0.007270   0.004815
# 2019-06-07   -0.008528   -0.006505   -0.100000   0.000000   0.013236
# ...                ...         ...         ...        ...        ...
# 2022-03-08    0.011026    0.016228    0.045455  -0.001616   0.014397
# 2022-03-09    0.029376    0.028359    0.086957   0.038025   0.028583
# 2022-03-10   -0.014867   -0.009585   -0.080000  -0.011061  -0.041778
# 2022-03-11   -0.008847   -0.015193   -0.043478  -0.008791   0.000000
# 2022-03-14    0.013126    0.006643   -0.090909  -0.006177   0.010600
#
#             COF return  STT return  FITB return  HSBC return  SIVB return
# Date
# 2019-06-03         NaN         NaN          NaN          NaN          NaN
# 2019-06-04    0.032614    0.029107     0.028604     0.008570     0.058635
# 2019-06-05   -0.000222   -0.033837    -0.005854    -0.001214    -0.011180
# 2019-06-06    0.005117    0.009698    -0.002944     0.000972     0.010505
# 2019-06-07   -0.001107    0.007115    -0.009598     0.006799    -0.007273
# ...                ...         ...          ...          ...          ...
# 2022-03-08    0.010256    0.015223    -0.000476     0.025499     0.045797
# 2022-03-09    0.046240    0.053175     0.066254     0.025821     0.042457
# 2022-03-10   -0.012509   -0.007897    -0.005811    -0.028278     0.001058
# 2022-03-11   -0.001305   -0.010010    -0.010791    -0.004797    -0.016533
# 2022-03-14    0.027519    0.015349     0.042045     0.022815    -0.034810
#
# [702 rows x 15 columns]

# %%
fig,axes = plt.subplots(nrows = 5, ncols = 3, figsize=(14,8))
plt.tight_layout(h_pad=1.5)
for tick, ax in zip(tickers, axes.flatten()):
    ax.hist(returns[tick +' return'], bins=100)
    ax.set_title(tick +' return')
